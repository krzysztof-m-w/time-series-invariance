# %%
from notebooks.presets import set_cwd
set_cwd()

import os
import numpy as np
from src.embeddings.shape_based import paa, sax, dtw_features
import matplotlib.pyplot as plt

# %%
data_path = "data/simple"
X  = []
labels = []
labels_names = []
names: list[str] = [i for i in range(10)]

for i, dir_name in enumerate(os.listdir(data_path)):

    dir_path = os.path.join(data_path, dir_name)
    vectors = []
    for f in os.listdir(dir_path):
        path = os.path.join(dir_path, f)
        a = np.load(path)
        v = sax(a, 10, 10)
        vectors.append(v)

    X.extend(vectors)
    labels.extend([i] * len(vectors))
    labels_names.append(dir_name)

# %%
from sklearn.metrics import silhouette_score
sil = silhouette_score(X, labels, metric="cosine")
print("Silhouette:", sil)
# Out:
# Silhouette: 0.9443712770266302

# %%
X = np.array(X)
X.shape
# Out:
# (35, 10)

# %%
group_size = 5

for i in range(X.shape[1]):
    column = X[:, i]

    groups = [column[j:j+group_size] 
              for j in range(0, len(column), group_size)]

    labels = [f"{labels_names[k]}" for k in range(len(groups))]

    plt.boxplot(groups, labels=labels)
    plt.title(names[i])
    plt.xticks(rotation=30)
    plt.show()
# Out:
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_9312\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
