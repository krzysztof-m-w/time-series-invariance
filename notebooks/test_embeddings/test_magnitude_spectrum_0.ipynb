# %%
from notebooks.presets import set_cwd
set_cwd()
import numpy as np
from src.embeddings.magnitude_spectrum import spectrum_descriptor, spectral_centroid, band_energy_ratios, mfcc_features
import os

# %%
example_path = "data/simple/parabolas_0/0.npy"

a = np.load(example_path)

# %%
spectrum_descriptor(a, 1)
# Out:
# (array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#         0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#         0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#         0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#         0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#         0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#         0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#         0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#         0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#         0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#         0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#         0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#         0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
# ...

# %%
spectral_centroid(a, 1)
# Out:
# np.float64(0.025046865437338344)

# %%
spectral_centroid(a[100:], 1)
# Out:
# np.float64(0.018560191513841136)

# %%
band_energy_ratios(a, 1, [(0, 0.1), (0.1, 0.3), (0.3, 0.5)])
# Out:
# [np.float64(0.9999622086939349),
#  np.float64(2.8850732672978162e-05),
#  np.float64(8.902095024427248e-06)]

# %%
mfcc_features(a, 1)
# Out:
# c:\Users\krzys\Documents\studia\time-series-invariance\.venv\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1000
#   warnings.warn(
# array([315.40877503,  68.18421884,  33.71204062,  22.38660409,
#         16.71748885,  13.36426815,  11.12455792,   9.54652652,
#          8.35988841,   7.44894608,   6.71774643,   6.12688759,
#          5.63250079])

# %%
dir_name = "data/simple/parabolas_0/"

# %%
a0 = np.load(os.path.join(dir_name, "0.npy"))
a1 = np.load(os.path.join(dir_name, "1.npy"))
a2 = np.load(os.path.join(dir_name, "2.npy"))
a3 = np.load(os.path.join(dir_name, "3.npy"))

# %%
print(spectral_centroid(a0, 100))
print(spectral_centroid(a1, 100))
print(spectral_centroid(a2, 100))
print(spectral_centroid(a3, 100))
# Out:
# 2.504686543733835
# 2.515332464350821
# 2.6736959980019175
# 2.752871454488321

# %%
print(band_energy_ratios(a0, 100, [(0, 25), (25, 50), (50, 75), (75, 100)]))
print(band_energy_ratios(a1, 100, [(0, 25), (25, 50), (50, 75), (75, 100)]))
print(band_energy_ratios(a2, 100, [(0, 25), (25, 50), (50, 75), (75, 100)]))
print(band_energy_ratios(a3, 100, [(0, 25), (25, 50), (50, 75), (75, 100)]))
# Out:
# [np.float64(0.9999877090521255), np.float64(1.2252469506758837e-05), np.float64(3.847836766155386e-08), np.float64(0.0)]
# [np.float64(0.9999865305608039), np.float64(1.342296284262051e-05), np.float64(4.6476353320753036e-08), np.float64(0.0)]
# [np.float64(0.9999843753047959), np.float64(1.5572247701955653e-05), np.float64(5.244750223719201e-08), np.float64(0.0)]
# [np.float64(0.9999772975081498), np.float64(2.270249185038116e-05), np.float64(0.0), np.float64(0.0)]

# %%
print(mfcc_features(a0, 100))
print(mfcc_features(a1, 100))
print(mfcc_features(a2, 100))
print(mfcc_features(a3, 100))
# Out:
# [89.13460506 68.18421885 33.71204061 22.3866041  16.71748887 13.36426816
#  11.12455791  9.54652654  8.35988843  7.44894609  6.71774643  6.1268876
#   5.63250082]
# [97.80052583 68.11960539 33.65175027 22.32332074 16.65717456 13.3009387
#  11.06420626  9.48317044  8.29951044  7.38558108  6.65734722  6.06350914
#   5.57206244]
# [97.0661923  68.11424421 33.64184894 22.3140465  16.64732161 13.29174287
#  11.05442618  9.47406202  8.28982435  7.37656591  6.64775437  6.05461103
#   5.56258214]
# [118.48651946  67.97739666  33.49729493  22.1791237   16.50254362
#   13.15671663  10.90960028   9.33900964   8.14503952   7.241606
#    6.50308672   5.91988227   5.41808021]
# c:\Users\krzys\Documents\studia\time-series-invariance\.venv\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1000
#   warnings.warn(
# ...
