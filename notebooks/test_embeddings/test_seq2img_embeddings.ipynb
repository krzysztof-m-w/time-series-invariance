# %%
from notebooks.presets import set_cwd
set_cwd()
from embeddings.seq2img_embeddings import s2i_vector
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
data_path = "data/simple"
X  = []
labels = []
labels_names = []
names: list[str]

for i, dir_name in enumerate(os.listdir(data_path)):

    dir_path = os.path.join(data_path, dir_name)
    vectors = []
    for f in os.listdir(dir_path):
        path = os.path.join(dir_path, f)
        a = np.load(path)
        v, names = s2i_vector(a)
        vectors.append(v)

    X.extend(vectors)
    labels.extend([i] * len(vectors))
    labels_names.append(dir_name)
# Out:
# c:\Users\krzys\Documents\studia\time-series-invariance\.venv\Lib\site-packages\pyts\preprocessing\discretizer.py:168: UserWarning: Some quantiles are equal. The number of bins will be smaller for sample [0]. Consider decreasing the number of bins or removing these samples.
#   warn("Some quantiles are equal. The number of bins will "
# c:\Users\krzys\Documents\studia\time-series-invariance\.venv\Lib\site-packages\pyts\preprocessing\discretizer.py:168: UserWarning: Some quantiles are equal. The number of bins will be smaller for sample [0]. Consider decreasing the number of bins or removing these samples.
#   warn("Some quantiles are equal. The number of bins will "
# c:\Users\krzys\Documents\studia\time-series-invariance\.venv\Lib\site-packages\pyts\preprocessing\discretizer.py:168: UserWarning: Some quantiles are equal. The number of bins will be smaller for sample [0]. Consider decreasing the number of bins or removing these samples.
# ...

# %%
from sklearn.metrics import silhouette_score
sil = silhouette_score(X, labels, metric="cosine")
print("Silhouette:", sil)
# Out:
# Silhouette: -0.023514734499739984

# %%
X = np.array(X)
X.shape
# Out:
# (35, 49)

# %%
group_size = 5

for i in range(X.shape[1]):
    column = X[:, i]

    groups = [column[j:j+group_size] 
              for j in range(0, len(column), group_size)]

    labels = [f"{labels_names[k]}" for k in range(len(groups))]

    plt.boxplot(groups, labels=labels)
    plt.title(names[i])
    plt.xticks(rotation=30)
    plt.show()
# Out:
# C:\Users\krzys\AppData\Local\Temp\ipykernel_2284\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_2284\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# C:\Users\krzys\AppData\Local\Temp\ipykernel_2284\3910806201.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=labels)
# ...
