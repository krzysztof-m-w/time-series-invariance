# %%
from notebooks.presets import set_cwd
set_cwd()
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
dir_path = "data/simple/parabolas"
for path in os.listdir(dir_path):
    a = np.load(os.path.join(dir_path, path))
    plt.plot(a)
    plt.show()
